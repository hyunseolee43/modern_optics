# %% [markdown]
# <p style="text-align: center;" ><font size="+3"><u><b>Lab 1: Alignment and Geometric Optics</u></b>
# <br>
# <font size="+1">Lab report due: <font color='red'> Midnight, Friday, Oct 2, 2026</font>
# </p>

# %% [markdown]
# <p style="text-align: left;" ><font size="+1"><b>Objectives</b></p>
# <font color=black>
#
# - Practice basic optical alignment and geometric optics techniques
# - Observe the image formation behavior in a finite and infinite conjugate imaging system
# - See how lateral, axial, and angular magnification determine the final image formed
#
# </font>

# %% [markdown]
# <p style="text-align: left;" ><font size="+1"><b>Basic Rules</b></p>
# <font color='black'> Before you start, remember:
#
# - Do not touch the lens surfaces directly; use a tissue and handle by the edges.
# - Do not look directly into the laser or point it at other people!
# - When aligning, do not put your eyes on the level of the beam, to avoid accidental reflections into your eye.
# - If your laser is sending stray light to other tables, use a book or paper etc. to block the beam.
#
#
#
# <b>Lab report: </b>
# Include answers to bolded questions in your group lab report. Please type question answers; handwritten drawings or calculations are ok, but make sure the final submission is a PDF file.
# </font>

# %% [markdown]
# # Basic alignment techniques
#
# <div class="alert alert-block alert-warning">
# <i>Laser alignment:</i> <font color='black'> Begin system setup with a straight, level laser beam starting from one end of the board.
# <br></br>
# Alignment is easiest with the beam parallel to breadboard holes. Observe the x and y positions (i.e., on the transverse plane perpendicular to optical axis) of the beam close to the diode output and at the opposite end of the board using the paper target attached to a mounting post (which acts as a vertical height marker) at the same lateral board locations. To describe the beam path as a line, remember you must have two points of reference to guide alignment.
# <br></br>
# Adjust laser using kinematic mount knobs, rotation about post, and/or translation of base until the beam is straight in the horizontal and vertical directions. <b>Include a picture of your setup/targets in the lab report. </b>
# </font>
# </div>

# %% [markdown]
# Put your image file in the same folder as the notebook and input the file name below to display the image.
# <img src="image-file-name.png" style="width:900px">

# %%
from IPython.display import Video
Video("lab1-laser-alignment.mp4",height=600)
# Out:
# <video src="lab1-laser-alignment.mp4" controls   height="600">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <i>Lens alignment:</i> <font color='black'> Now practice aligning the 30 mm lens in the beam path ~1f + several extra cm from the laser. Note that you may have to correct tilt and position errors iteratively.
# <br></br>
# Place the paper target about 1f beyond the incoming lens position and note the beam location. Roughly center the mounted lens by observing where the laser falls on the front surface of the lens; does the beam appear in the same location?
# <br></br>
# For lateral alignment, first move the lens back and forth in the transverse plane perpendicular to the beam. <b>What changes do you observe in the position of the light on the target? Explain using your knowledge of geometric optics</b> (Hint: Consider ray tracing for a lens with an ‘optical axis’ collinear or far from the beam’s optical axis). Adjust the lens lateral position so that the beam is located at the pre-lens position.
# <br></br>
# Tilt error can be corrected by guiding the reflection off of the lens surface back into the path it originated from (Note: reflection may be small depending on source brightness; most lenses we are using are anti-reflection coated. If you are interested in learning more about the surface reflections, check out the Fresnel equations https://www.rp-photonics.com/fresnel_equations.html).
# </font>
# </div>

# %% [markdown]
# Enter your answer here.

# %%
Video("lab1-lens-alignment.mp4",height=600)
# Out:
# <video src="lab1-lens-alignment.mp4" controls   height="600">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# # Basic geometric optics
#
# <div class="alert alert-block alert-warning">
# <i>Principal rays:</i> <font color='black'> In class, three different principal rays for a lens were discussed. Recall these three rays and their relationships to a lens and its focal length. Try to experimentally recreate two of these rays with your laser and 30 mm lens, specifically the ray traveling through the center of a lens and the ray traveling parallel to the optical axis. <b>Record the result from the two setups.</b>
# <br></br>
# <i>NOTE:</i> It will be difficult to ensure that your beam is traveling parallel to the optical axis, especially as the tilt of the lens is difficult to accurately tune. Try to control this to the best of your ability and use the breadboard markings as a reference whenever possible. Further, the interaction of the beam with the single lens will change the beam shape as it propagates. Try to think about the general propagation direction and not the beam shape when trying to observe the principal rays.
# </font>
# </div>

# %% [markdown]
# Put your image file in the same folder as the notebook and input the file name below to display the image.
# <img src="image-file-name.png" style="width:900px">

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <i>Estimation of focal length:</i> <font color='black'> Next you will be estimating the focal length of the lens. For the illumination source, place the laser on a mounting post. Direct the beam along a line of the breadboard. You can confirm this with a mounting post and ensuring the beam is at about the same height and lateral position at multiple different points along the path (see 1a). Now position the R1L1SN1 calibration tool so the laser illuminates the pattern along the breadboard axis. This will be your object. Now place a lens of your choice along the same pathway as the laser. Use a piece of paper (as screen) to find where the image of the object is formed most sharply. Record the distance from the object to the lens, and from the lens to the image. <b>Use these measurements and the thin lens formula to estimate the focal length of the lens.</b> Repeat the process for a few different object distances to <b>find an average focal length for the lens. Include focal length, raw measurements, and your calculation in the report.</b>
# </font>
# </div>

# %% [markdown]
# The table below
# | **D_o (object distance)** | **D_i (image distance)** | **Focal length** |
# |---:|---:|---:|
# | 56 | 65 | 30.0826446 |
# | 51 | 78 | 30.8372093 |
# | 46 | 90 | 30.4411765 |
# | 40 | 105 | 28.9655172 |
# | 60 | 55 | 28.6956522 |

# %%
Video("lab1-mount_Target.mp4",height=600)
# Out:
# <video src="lab1-mount_Target.mp4" controls   height="600">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# # Finite and infinite conjugate imaging
#
# <div class="alert alert-block alert-warning">
#     <font color='black'>
# Keeping the laser and 30 mm lens aligned, add and align the 150 mm lens in the optical path to set the lenses 2f apart. Note: “2f” means two focal lengths. In this case, this means f1+f2. <b>What should the output beam look like if the lenses are 2f apart? Verify the beam size at several distances from the second lens.</b>
# </font>
# </div>

# %% [markdown]
# Enter your answer here.

# %%
Video("lab1-2f-system.mp4",height=600)
# Out:
# <video src="lab1-2f-system.mp4" controls   height="600">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color='black'>
#
# You will now use the alignment of the 2f lenses to create a 4f system. Place the R1L1S1N calibration tool in the optical path so that the laser illuminates the grid pattern. Change the axial position of the tool to try and place it at the focal length of the first lens. Add a mirror or beamsplitter between the first and second lenses to create a long image distance as a reference. Adjust the position between the calibration glass (object) and the first lens while observing the image formed beyond the mirror until you observe the expected pattern that results from alignment at the focal length. Using the lens equation,<b> calculate the magnification of the overall relay. Compare the magnification with object and image measurements.</b>
#
# </font>
# </div>

# %% [markdown]
# Enter your answer here.

# %% [markdown]
# <img src="lab1-conjugate-imaging.jpg" style="width:900px">

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color='black'>
#
# Change the spacing between the first and second lenses.<b> Does the final image position change relative to this second lens? Why or why not should this be the case? Does placing the beamsplitter between the lenses cause a change in the final image? </b>
#
# </font>
# </div>

# %% [markdown]
# Focuses at focal length, focal length doesn't change so the final image doesn't change.
#
# The beamsplitter doesn't change the final image

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color='black'>
#
# Remove the beamsplitter and move the resolution target (R1L1SN1) so that it is located more than 1f before the first lens. <b> Where does the intermediate image form? Does the spacing between the first and second lens change the final image size and position relative to the second lens? How does this agree with your knowledge of a finite conjugate system? </b>
#
#
# </font>
# </div>

# %% [markdown]
# The intermediate image is formed between 1*f1 and 2*f1 from the first lens towards the second lens
# Yes it does.
# The ef

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <font color='black'>
# <b>Again calculate the magnification of the system for the new object location. Connect these measurements to your understanding of finite and infinite conjugate imaging systems. </b>
#
#
# </font>
# </div>

# %% [markdown]
# object to lens1: 3.6 cm
# lens1 to lens 2: 6 cm
# lens2 to image: 23.5 cm
#
# size of 3 stripes at 5 5 : 4 mm

# %% [markdown]
# # Axial/Lateral magnification (if time)
#
# <div class="alert alert-block alert-warning">
#     <font color='black'>
# <i>NOTE: By moving the optical elements, your system may have become misaligned! Try to recover proper alignment to make sure your measurements are as accurate as possible! </i>
#
# In this section of the lab, you will observe the relationships between lateral, axial, and angular magnification. Recall the relationship between these three properties. Use the 4f system from question 3. <b>Estimate the lateral and axial magnification at different positions along the optical axis by moving your object along the optical axis. Use these measurements to calculate the angular magnification.</b> Recall that axial magnification is the scaling of depth in the image plane.
# </font>
# </div>

# %% [markdown]
# Enter your answer here.
